# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravvxv/Pandas/blob/main/Notebook/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Practice Notebook**

# %% [markdown]
# **Pandas is a python library used for data manipulation, Data analysis, and Data cleaning. It Provides easy to use data structure like series (1D) and DataFrame (2d), Which allow us to store and manage tabular data effiently**

# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Connecting to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read csv file

# %%
path = '/content/drive/MyDrive/Movies Data/netflix_titles.csv'

# %%
df = pd.read_csv(path)

# %% [markdown]
# # Get top 5 data using head

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# # Getting last 5 data using tail

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# # Get Rows and Columns

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Get columns name

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Get Datatypes

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # Summary of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # Selection & Filtering

# %%
# select column
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# select multiple column

df[['title','type']]
# Out:
#                       title     type
# 0      Dick Johnson Is Dead    Movie
# 1             Blood & Water  TV Show
# 2                 Ganglands  TV Show
# 3     Jailbirds New Orleans  TV Show
# 4              Kota Factory  TV Show
# ...                     ...      ...
# 8802                 Zodiac    Movie
# 8803            Zombie Dumb  TV Show
# 8804             Zombieland    Movie
# 8805                   Zoom    Movie
# 8806                 Zubaan    Movie
#
# [8807 rows x 2 columns]

# %% [markdown]
# **loc**

# %%
df.loc[0:10,['title','type']]
# Out:
#                                   title     type
# 0                  Dick Johnson Is Dead    Movie
# 1                         Blood & Water  TV Show
# 2                             Ganglands  TV Show
# 3                 Jailbirds New Orleans  TV Show
# 4                          Kota Factory  TV Show
# 5                         Midnight Mass  TV Show
# 6      My Little Pony: A New Generation    Movie
# 7                               Sankofa    Movie
# 8         The Great British Baking Show  TV Show
# 9                          The Starling    Movie
# 10  Vendetta: Truth, Lies and The Mafia  TV Show

# %% [markdown]
# **iloc**

# %%
df.iloc[0:10,2]
# Out:
# 0                Dick Johnson Is Dead
# 1                       Blood & Water
# 2                           Ganglands
# 3               Jailbirds New Orleans
# 4                        Kota Factory
# 5                       Midnight Mass
# 6    My Little Pony: A New Generation
# 7                             Sankofa
# 8       The Great British Baking Show
# 9                        The Starling
# Name: title, dtype: object

# %%
df[df['release_year']<2017]
# Out:
#      show_id   type            title         director  \
# 7         s8  Movie          Sankofa     Haile Gerima
# 22       s23  Movie  Avvai Shanmughi   K.S. Ravikumar
# 24       s25  Movie            Jeans       S. Shankar
# 26       s27  Movie   Minsara Kanavu      Rajiv Menon
# 27       s28  Movie        Grown Ups     Dennis Dugan
# ...      ...    ...              ...              ...
# 8801   s8802  Movie          Zinzana  Majid Al Ansari
# 8802   s8803  Movie           Zodiac    David Fincher
# 8804   s8805  Movie       Zombieland  Ruben Fleischer
# 8805   s8806  Movie             Zoom     Peter Hewitt
# 8806   s8807  Movie           Zubaan      Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 26    Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P....
# 27    Adam Sandler, Kevin James, Chris Rock, David S...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 22                                                  NaN  September 21, 2021
# 24                                                India  September 21, 2021
# 26                                                  NaN  September 21, 2021
# 27                                        United States  September 20, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#       release_year rating duration  \
# 7             1993  TV-MA  125 min
# 22            1996  TV-PG  161 min
# 24            1998  TV-14  166 min
# 26            1997  TV-PG  147 min
# 27            2010  PG-13  103 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 22                      Comedies, International Movies
# 24     Comedies, International Movies, Romantic Movies
# 26    Comedies, International Movies, Music & Musicals
# 27                                            Comedies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description
# 7     On a photo shoot in Ghana, an American model s...
# 22    Newly divorced and denied visitation rights wi...
# 24    When the father of the man she loves insists t...
# 26    A tangled love triangle ensues when a man fall...
# 27    Mourning the loss of their beloved junior high...
# ...                                                 ...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [4053 rows x 12 columns]

# %%
df.query('release_year>2017')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8752   s8753    Movie               Wish Man      Theo Davies
# 8756   s8757    Movie              Woodstock    Barak Goodman
# 8774   s8775    Movie              يوم الدين  Abu Bakr Shawky
# 8775   s8776  TV Show        Yeh Meri Family              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                   NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...                                                 ...
# 8752  Andrew Steel, Kirby Bliss Blanton, Tom Sizemor...
# 8756                                                NaN
# 8774  Rady Gamal, Ahmed Abdelhafiz, Shahira Fahmy, S...
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...
# 8803                                                NaN
#
#                             country          date_added  release_year rating  \
# 0                     United States  September 25, 2021          2020  PG-13
# 1                      South Africa  September 24, 2021          2021  TV-MA
# 2                               NaN  September 24, 2021          2021  TV-MA
# 3                               NaN  September 24, 2021          2021  TV-MA
# 4                             India  September 24, 2021          2021  TV-MA
# ...                             ...                 ...           ...    ...
# 8752                  United States    December 3, 2019          2019  TV-14
# 8756                  United States     August 13, 2019          2019  TV-MA
# 8774  Egypt, Austria, United States    October 22, 2019          2018  TV-14
# 8775                          India     August 31, 2018          2018  TV-PG
# 8803                            NaN        July 1, 2019          2018  TV-Y7
#
#        duration                                          listed_in  \
# 0        90 min                                      Documentaries
# 1     2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2      1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3      1 Season                             Docuseries, Reality TV
# 4     2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# ...         ...                                                ...
# 8752    108 min                   Children & Family Movies, Dramas
# 8756     97 min                    Documentaries, Music & Musicals
# 8774     97 min   Dramas, Independent Movies, International Movies
# 8775   1 Season                International TV Shows, TV Comedies
# 8803  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8752  After surviving a life-threatening accident, a...
# 8756  For the 50th anniversary of the legendary Wood...
# 8774  A man cured of leprosy and a young orphan leav...
# 8775  In the summer of 1998, middle child Harshu bal...
# 8803  While living alone in a spooky town, a young g...
#
# [3722 rows x 12 columns]

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # **Modifying Data**

# %%
df['release_month_date'] = df['date_added'].str.split(',').str[0]

df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description release_month_date
# 0     As her father nears the end of his life, filmm...       September 25
# 1     After crossing paths at a party, a Cape Town t...       September 24
# 2     To protect his family from a powerful drug lor...       September 24
# 3     Feuds, flirtations and toilet talk go down amo...       September 24
# 4     In a city of coaching centers known to train I...       September 24
# ...                                                 ...                ...
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8803  While living alone in a spooky town, a young g...             July 1
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [8807 rows x 13 columns]

# %%
df.rename(columns={'release_date':'Release_time'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description release_month_date
# 0     As her father nears the end of his life, filmm...       September 25
# 1     After crossing paths at a party, a Cape Town t...       September 24
# 2     To protect his family from a powerful drug lor...       September 24
# 3     Feuds, flirtations and toilet talk go down amo...       September 24
# 4     In a city of coaching centers known to train I...       September 24
# ...                                                 ...                ...
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8803  While living alone in a spooky town, a young g...             July 1
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [8807 rows x 13 columns]

# %%
df.dtypes
# Out:
# show_id               object
# type                  object
# title                 object
# director              object
# cast                  object
# country               object
# date_added            object
# release_year           int64
# rating                object
# duration              object
# listed_in             object
# description           object
# release_month_date    object
# dtype: object

# %%
df =df.astype({'release_year':str})

# %%
df.dtypes
# Out:
# show_id               object
# type                  object
# title                 object
# director              object
# cast                  object
# country               object
# date_added            object
# release_year          object
# rating                object
# duration              object
# listed_in             object
# description           object
# release_month_date    object
# dtype: object

# %%
df['release_month_date'] = df['release_month_date'].replace('September 24','October 04')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added release_year rating   duration  \
# 0     September 25, 2021         2020  PG-13     90 min
# 1     September 24, 2021         2021  TV-MA  2 Seasons
# 2     September 24, 2021         2021  TV-MA   1 Season
# 3     September 24, 2021         2021  TV-MA   1 Season
# 4     September 24, 2021         2021  TV-MA  2 Seasons
# ...                  ...          ...    ...        ...
# 8802   November 20, 2019         2007      R    158 min
# 8803        July 1, 2019         2018  TV-Y7  2 Seasons
# 8804    November 1, 2019         2009      R     88 min
# 8805    January 11, 2020         2006     PG     88 min
# 8806       March 2, 2019         2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description release_month_date
# 0     As her father nears the end of his life, filmm...       September 25
# 1     After crossing paths at a party, a Cape Town t...         October 04
# 2     To protect his family from a powerful drug lor...         October 04
# 3     Feuds, flirtations and toilet talk go down amo...         October 04
# 4     In a city of coaching centers known to train I...         October 04
# ...                                                 ...                ...
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8803  While living alone in a spooky town, a young g...             July 1
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [8807 rows x 13 columns]

# %%
df.drop(columns=['DATE_ADDED'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-07055071b597> in <cell line: 0>()
# ----> 1 df.drop(columns=['DATE_ADDED'],inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['DATE_ADDED'] not found in axis"

# %%
df.drop(index = 3)
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water              NaN
# 2         s3  TV Show             Ganglands  Julien Leclercq
# 4         s5  TV Show          Kota Factory              NaN
# 5         s6  TV Show         Midnight Mass    Mike Flanagan
# ...      ...      ...                   ...              ...
# 8802   s8803    Movie                Zodiac    David Fincher
# 8803   s8804  TV Show           Zombie Dumb              NaN
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added release_year rating   duration  \
# 0     September 25, 2021         2020  PG-13     90 min
# 1     September 24, 2021         2021  TV-MA  2 Seasons
# 2     September 24, 2021         2021  TV-MA   1 Season
# 4     September 24, 2021         2021  TV-MA  2 Seasons
# 5     September 24, 2021         2021  TV-MA   1 Season
# ...                  ...          ...    ...        ...
# 8802   November 20, 2019         2007      R    158 min
# 8803        July 1, 2019         2018  TV-Y7  2 Seasons
# 8804    November 1, 2019         2009      R     88 min
# 8805    January 11, 2020         2006     PG     88 min
# 8806       March 2, 2019         2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description release_month_date
# 0     As her father nears the end of his life, filmm...       September 25
# 1     After crossing paths at a party, a Cape Town t...         October 04
# 2     To protect his family from a powerful drug lor...         October 04
# 4     In a city of coaching centers known to train I...         October 04
# 5     The arrival of a charismatic young priest brin...         October 04
# ...                                                 ...                ...
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8803  While living alone in a spooky town, a young g...             July 1
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [8806 rows x 13 columns]

# %%
df.columns = df.columns.to_series().apply(lambda x: x.upper())

# %%
df.head()
# Out:
#   SHOW_ID     TYPE                  TITLE         DIRECTOR  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 CAST        COUNTRY  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            DATE_ADDED RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
# 2  September 24, 2021         2021  TV-MA   1 Season
# 3  September 24, 2021         2021  TV-MA   1 Season
# 4  September 24, 2021         2021  TV-MA  2 Seasons
#
#                                            LISTED_IN  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          DESCRIPTION RELEASE_MONTH_DATE
# 0  As her father nears the end of his life, filmm...       September 25
# 1  After crossing paths at a party, a Cape Town t...         October 04
# 2  To protect his family from a powerful drug lor...         October 04
# 3  Feuds, flirtations and toilet talk go down amo...         October 04
# 4  In a city of coaching centers known to train I...         October 04

# %% [markdown]
# # Handling Missing Data

# %%
df.isnull().sum()
# Out:
# SHOW_ID                  0
# TYPE                     0
# TITLE                    0
# DIRECTOR              2634
# CAST                   825
# COUNTRY                831
# DATE_ADDED              10
# RELEASE_YEAR             0
# RATING                   4
# DURATION                 3
# LISTED_IN                0
# DESCRIPTION              0
# RELEASE_MONTH_DATE      10
# dtype: int64

# %%
df.notnull().sum()
# Out:
# SHOW_ID               8807
# TYPE                  8807
# TITLE                 8807
# DIRECTOR              6173
# CAST                  7982
# COUNTRY               7976
# DATE_ADDED            8797
# RELEASE_YEAR          8807
# RATING                8803
# DURATION              8804
# LISTED_IN             8807
# DESCRIPTION           8807
# RELEASE_MONTH_DATE    8797
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# SHOW_ID               0
# TYPE                  0
# TITLE                 0
# DIRECTOR              0
# CAST                  0
# COUNTRY               0
# DATE_ADDED            0
# RELEASE_YEAR          0
# RATING                0
# DURATION              0
# LISTED_IN             0
# DESCRIPTION           0
# RELEASE_MONTH_DATE    0
# dtype: int64

# %%
df.notnull()
# Out:
#       SHOW_ID  TYPE  TITLE  DIRECTOR  CAST  COUNTRY  DATE_ADDED  RELEASE_YEAR  \
# 7        True  True   True      True  True     True        True          True
# 8        True  True   True      True  True     True        True          True
# 9        True  True   True      True  True     True        True          True
# 12       True  True   True      True  True     True        True          True
# 24       True  True   True      True  True     True        True          True
# ...       ...   ...    ...       ...   ...      ...         ...           ...
# 8801     True  True   True      True  True     True        True          True
# 8802     True  True   True      True  True     True        True          True
# 8804     True  True   True      True  True     True        True          True
# 8805     True  True   True      True  True     True        True          True
# 8806     True  True   True      True  True     True        True          True
#
#       RATING  DURATION  LISTED_IN  DESCRIPTION  RELEASE_MONTH_DATE
# 7       True      True       True         True                True
# 8       True      True       True         True                True
# 9       True      True       True         True                True
# 12      True      True       True         True                True
# 24      True      True       True         True                True
# ...      ...       ...        ...          ...                 ...
# 8801    True      True       True         True                True
# 8802    True      True       True         True                True
# 8804    True      True       True         True                True
# 8805    True      True       True         True                True
# 8806    True      True       True         True                True
#
# [5332 rows x 13 columns]

# %%
df.fillna('Not present')
# Out:
#      SHOW_ID     TYPE                          TITLE             DIRECTOR  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    CAST  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 COUNTRY          DATE_ADDED  \
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                        United Kingdom  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# 24                                                India  September 21, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#      RELEASE_YEAR RATING   DURATION  \
# 7            1993  TV-MA    125 min
# 8            2021  TV-14  9 Seasons
# 9            2021  PG-13    104 min
# 12           2021  TV-MA    127 min
# 24           1998  TV-14    166 min
# ...           ...    ...        ...
# 8801         2015  TV-MA     96 min
# 8802         2007      R    158 min
# 8804         2009      R     88 min
# 8805         2006     PG     88 min
# 8806         2015  TV-14    111 min
#
#                                              LISTED_IN  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             DESCRIPTION RELEASE_MONTH_DATE
# 7     On a photo shoot in Ghana, an American model s...         October 04
# 8     A talented batch of amateur bakers face off in...         October 04
# 9     A woman adjusting to life after a loss contend...         October 04
# 12    After most of her family is murdered in a terr...       September 23
# 24    When the father of the man she loves insists t...       September 21
# ...                                                 ...                ...
# 8801  Recovering alcoholic Talal wakes up inside a s...            March 9
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [5332 rows x 13 columns]

# %% [markdown]
# # **Grouping and Aggregation**

# %%
group = df.groupby('RELEASE_YEAR')['RELEASE_MONTH_DATE'].sum()
group.head(10)
# Out:
# RELEASE_YEAR
# 1942                            March 31
# 1944                            March 31
# 1945                            March 31
# 1946                            March 31
# 1947                            March 31
# 1954                  November 15June 18
# 1955    November 1November 13November 13
# 1956                   June 18November 1
# 1958         June 18November 1November 1
# 1959                              July 6
# Name: RELEASE_MONTH_DATE, dtype: object

# %%
df.agg({'DURATION':['sum']})
# Out:
#                                               DURATION
# sum  125 min9 Seasons104 min127 min166 min103 min97...

# %%
df['RELEASE_MONTH_DATE'].value_counts()
# Out:
# RELEASE_MONTH_DATE
# January 1      219
# October 1      182
# November 1     169
# July 1         160
# September 1    139
#               ...
# August 22        2
#  August 4        1
#  November 1      1
#  March 31        1
#  May 18          1
# Name: count, Length: 369, dtype: int64

# %% [markdown]
# # **Sorting and rearranging**

# %%
df.sort_values('RELEASE_YEAR')
# Out:
#      SHOW_ID   TYPE                                       TITLE  \
# 8205   s8206  Movie                        The Battle of Midway
# 8640   s8641  Movie                            Tunisian Victory
# 7219   s7220  Movie                     Know Your Enemy - Japan
# 7294   s7295  Movie                          Let There Be Light
# 8587   s8588  Movie                                 Thunderbolt
# ...      ...    ...                                         ...
# 1151   s1152  Movie                Octonauts & the Ring of Fire
# 881     s882  Movie                              I Am All Girls
# 1156   s1157  Movie                                 A Week Away
# 1412   s1413  Movie                                    Wish You
# 1304   s1305  Movie  Animals on the Loose: A You vs. Wild Movie
#
#                                                DIRECTOR  \
# 8205                                          John Ford
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# 7219                           Frank Capra, Joris Ivens
# 7294                                        John Huston
# 8587                        William Wyler, John Sturges
# ...                                                 ...
# 1151                                      Blair Simmons
# 881                                       Donovan Marsh
# 1156                                        Roman White
# 1412                                        Sung Do-jun
# 1304                                          Ben Simms
#
#                                                    CAST  \
# 8205                          Henry Fonda, Jane Darwell
# 8640                                   Burgess Meredith
# 7219                        Walter Huston, Dana Andrews
# 7294                                      Walter Huston
# 8587                       James Stewart, Lloyd Bridges
# ...                                                 ...
# 1151  Simon Greenall, Rob Rackstraw, Jo Wyatt, Paul ...
# 881   Erica Wessels, Hlubi Mboya, Deon Lotz, Brendon...
# 1156  Kevin Quinn, Bailee Madison, Jahbril Cook, Kat...
# 1412                     Kang In-soo, Lee Sang, Soo-bin
# 1304                                        Bear Grylls
#
#                             COUNTRY         DATE_ADDED RELEASE_YEAR RATING  \
# 8205                  United States     March 31, 2017         1942  TV-14
# 8640  United States, United Kingdom     March 31, 2017         1944  TV-14
# 7219                  United States     March 31, 2017         1945  TV-14
# 7294                  United States     March 31, 2017         1946  TV-PG
# 8587                  United States     March 31, 2017         1947  TV-PG
# ...                             ...                ...          ...    ...
# 1151          China, United Kingdom     March 30, 2021         2021   TV-Y
# 881                    South Africa       May 14, 2021         2021  TV-MA
# 1156                  United States     March 26, 2021         2021  TV-PG
# 1412                    South Korea   January 15, 2021         2021  TV-PG
# 1304                  United States  February 16, 2021         2021  TV-PG
#
#      DURATION                                          LISTED_IN  \
# 8205   18 min                      Classic Movies, Documentaries
# 8640   76 min                      Classic Movies, Documentaries
# 7219   63 min                      Classic Movies, Documentaries
# 7294   58 min                      Classic Movies, Documentaries
# 8587   42 min                      Classic Movies, Documentaries
# ...       ...                                                ...
# 1151   73 min                           Children & Family Movies
# 881   107 min            Dramas, International Movies, Thrillers
# 1156   98 min  Children & Family Movies, Faith & Spirituality...
# 1412  102 min         Dramas, International Movies, LGBTQ Movies
# 1304  139 min                           Children & Family Movies
#
#                                             DESCRIPTION RELEASE_MONTH_DATE
# 8205  Director John Ford captures combat footage of ...           March 31
# 8640  British and American troops join forces to lib...           March 31
# 7219  Though culturally insensitive by modern standa...           March 31
# 7294  Some returning combat veterans suffer scars th...           March 31
# 8587  A P-47 Thunderbolt squadron is shown in prepar...           March 31
# ...                                                 ...                ...
# 1151  When red-hot volcanoes start a chain reaction ...           March 30
# 881   A relentless detective finds common ground wit...             May 14
# 1156  In this uplifting musical, a troubled teen tak...           March 26
# 1412  Singing and dreaming together, a talented sing...         January 15
# 1304  When wild animals escape from a sanctuary, Bea...        February 16
#
# [5332 rows x 13 columns]

# %%
df.sort_index()
# Out:
#      SHOW_ID     TYPE                          TITLE             DIRECTOR  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    CAST  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 COUNTRY          DATE_ADDED  \
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                        United Kingdom  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# 24                                                India  September 21, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#      RELEASE_YEAR RATING   DURATION  \
# 7            1993  TV-MA    125 min
# 8            2021  TV-14  9 Seasons
# 9            2021  PG-13    104 min
# 12           2021  TV-MA    127 min
# 24           1998  TV-14    166 min
# ...           ...    ...        ...
# 8801         2015  TV-MA     96 min
# 8802         2007      R    158 min
# 8804         2009      R     88 min
# 8805         2006     PG     88 min
# 8806         2015  TV-14    111 min
#
#                                              LISTED_IN  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             DESCRIPTION RELEASE_MONTH_DATE
# 7     On a photo shoot in Ghana, an American model s...         October 04
# 8     A talented batch of amateur bakers face off in...         October 04
# 9     A woman adjusting to life after a loss contend...         October 04
# 12    After most of her family is murdered in a terr...       September 23
# 24    When the father of the man she loves insists t...       September 21
# ...                                                 ...                ...
# 8801  Recovering alcoholic Talal wakes up inside a s...            March 9
# 8802  A political cartoonist, a crime reporter and a...        November 20
# 8804  Looking to survive in a world taken over by zo...         November 1
# 8805  Dragged from civilian life, a former superhero...         January 11
# 8806  A scrappy but poor boy worms his way into a ty...            March 2
#
# [5332 rows x 13 columns]

# %%
df.reset_index()
# Out:
#       index SHOW_ID     TYPE                          TITLE  \
# 0         7      s8    Movie                        Sankofa
# 1         8      s9  TV Show  The Great British Baking Show
# 2         9     s10    Movie                   The Starling
# 3        12     s13    Movie                   Je Suis Karl
# 4        24     s25    Movie                          Jeans
# ...     ...     ...      ...                            ...
# 5327   8801   s8802    Movie                        Zinzana
# 5328   8802   s8803    Movie                         Zodiac
# 5329   8804   s8805    Movie                     Zombieland
# 5330   8805   s8806    Movie                           Zoom
# 5331   8806   s8807    Movie                         Zubaan
#
#                  DIRECTOR                                               CAST  \
# 0            Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1         Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2          Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3     Christian Schwochow  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 4              S. Shankar  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                   ...                                                ...
# 5327      Majid Al Ansari  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 5328        David Fincher  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 5329      Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 5330         Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 5331          Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 COUNTRY          DATE_ADDED  \
# 0     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 1                                        United Kingdom  September 24, 2021
# 2                                         United States  September 24, 2021
# 3                               Germany, Czech Republic  September 23, 2021
# 4                                                 India  September 21, 2021
# ...                                                 ...                 ...
# 5327                       United Arab Emirates, Jordan       March 9, 2016
# 5328                                      United States   November 20, 2019
# 5329                                      United States    November 1, 2019
# 5330                                      United States    January 11, 2020
# 5331                                              India       March 2, 2019
#
#      RELEASE_YEAR RATING   DURATION  \
# 0            1993  TV-MA    125 min
# 1            2021  TV-14  9 Seasons
# 2            2021  PG-13    104 min
# 3            2021  TV-MA    127 min
# 4            1998  TV-14    166 min
# ...           ...    ...        ...
# 5327         2015  TV-MA     96 min
# 5328         2007      R    158 min
# 5329         2009      R     88 min
# 5330         2006     PG     88 min
# 5331         2015  TV-14    111 min
#
#                                              LISTED_IN  \
# 0     Dramas, Independent Movies, International Movies
# 1                         British TV Shows, Reality TV
# 2                                     Comedies, Dramas
# 3                         Dramas, International Movies
# 4      Comedies, International Movies, Romantic Movies
# ...                                                ...
# 5327           Dramas, International Movies, Thrillers
# 5328                    Cult Movies, Dramas, Thrillers
# 5329                           Comedies, Horror Movies
# 5330                Children & Family Movies, Comedies
# 5331    Dramas, International Movies, Music & Musicals
#
#                                             DESCRIPTION RELEASE_MONTH_DATE
# 0     On a photo shoot in Ghana, an American model s...         October 04
# 1     A talented batch of amateur bakers face off in...         October 04
# 2     A woman adjusting to life after a loss contend...         October 04
# 3     After most of her family is murdered in a terr...       September 23
# 4     When the father of the man she loves insists t...       September 21
# ...                                                 ...                ...
# 5327  Recovering alcoholic Talal wakes up inside a s...            March 9
# 5328  A political cartoonist, a crime reporter and a...        November 20
# 5329  Looking to survive in a world taken over by zo...         November 1
# 5330  Dragged from civilian life, a former superhero...         January 11
# 5331  A scrappy but poor boy worms his way into a ty...            March 2
#
# [5332 rows x 14 columns]

# %%
df.set_index('SHOW_ID')
# Out:
#             TYPE                          TITLE             DIRECTOR  \
# SHOW_ID
# s8         Movie                        Sankofa         Haile Gerima
# s9       TV Show  The Great British Baking Show      Andy Devonshire
# s10        Movie                   The Starling       Theodore Melfi
# s13        Movie                   Je Suis Karl  Christian Schwochow
# s25        Movie                          Jeans           S. Shankar
# ...          ...                            ...                  ...
# s8802      Movie                        Zinzana      Majid Al Ansari
# s8803      Movie                         Zodiac        David Fincher
# s8805      Movie                     Zombieland      Ruben Fleischer
# s8806      Movie                           Zoom         Peter Hewitt
# s8807      Movie                         Zubaan          Mozez Singh
#
#                                                       CAST  \
# SHOW_ID
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s9       Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# s25      Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                    ...
# s8802    Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                    COUNTRY  \
# SHOW_ID
# s8       United States, Ghana, Burkina Faso, United Kin...
# s9                                          United Kingdom
# s10                                          United States
# s13                                Germany, Czech Republic
# s25                                                  India
# ...                                                    ...
# s8802                         United Arab Emirates, Jordan
# s8803                                        United States
# s8805                                        United States
# s8806                                        United States
# s8807                                                India
#
#                  DATE_ADDED RELEASE_YEAR RATING   DURATION  \
# SHOW_ID
# s8       September 24, 2021         1993  TV-MA    125 min
# s9       September 24, 2021         2021  TV-14  9 Seasons
# s10      September 24, 2021         2021  PG-13    104 min
# s13      September 23, 2021         2021  TV-MA    127 min
# s25      September 21, 2021         1998  TV-14    166 min
# ...                     ...          ...    ...        ...
# s8802         March 9, 2016         2015  TV-MA     96 min
# s8803     November 20, 2019         2007      R    158 min
# s8805      November 1, 2019         2009      R     88 min
# s8806      January 11, 2020         2006     PG     88 min
# s8807         March 2, 2019         2015  TV-14    111 min
#
#                                                 LISTED_IN  \
# SHOW_ID
# s8       Dramas, Independent Movies, International Movies
# s9                           British TV Shows, Reality TV
# s10                                      Comedies, Dramas
# s13                          Dramas, International Movies
# s25       Comedies, International Movies, Romantic Movies
# ...                                                   ...
# s8802             Dramas, International Movies, Thrillers
# s8803                      Cult Movies, Dramas, Thrillers
# s8805                             Comedies, Horror Movies
# s8806                  Children & Family Movies, Comedies
# s8807      Dramas, International Movies, Music & Musicals
#
#                                                DESCRIPTION RELEASE_MONTH_DATE
# SHOW_ID
# s8       On a photo shoot in Ghana, an American model s...         October 04
# s9       A talented batch of amateur bakers face off in...         October 04
# s10      A woman adjusting to life after a loss contend...         October 04
# s13      After most of her family is murdered in a terr...       September 23
# s25      When the father of the man she loves insists t...       September 21
# ...                                                    ...                ...
# s8802    Recovering alcoholic Talal wakes up inside a s...            March 9
# s8803    A political cartoonist, a crime reporter and a...        November 20
# s8805    Looking to survive in a world taken over by zo...         November 1
# s8806    Dragged from civilian life, a former superhero...         January 11
# s8807    A scrappy but poor boy worms his way into a ty...            March 2
#
# [5332 rows x 12 columns]

# %%
data = {
  'Department': ['Sales', 'Sales', 'HR', 'HR', 'IT', 'IT'],
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M'],
    'Salary': [50000, 55000, 48000, 51000, 60000, 62000]
}

df1 = pd.DataFrame(data)

# %%
df1
# Out:
#   Department Gender  Salary
# 0      Sales      F   50000
# 1      Sales      M   55000
# 2         HR      M   48000
# 3         HR      M   51000
# 4         IT      F   60000
# 5         IT      M   62000

# %%
pivot = df1.pivot_table(index='Department',columns='Gender',values='Salary',aggfunc='sum')
pivot.fillna('Not present')
# Out:
# Gender                F        M
# Department
# HR          Not present  99000.0
# IT              60000.0  62000.0
# Sales           50000.0  55000.0

# %%
data2 = {
  'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']
}

data3 = {
  'Name': ['Linda', 'Amil', 'Cherry', 'Sam'],
    'Age': [22, 345, 11, 23],
    'City': ['Thailand', 'America', 'Spain', 'London']
}


df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)


df2
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago

# %%
df3
# Out:
#      Name  Age      City
# 0   Linda   22  Thailand
# 1    Amil  345   America
# 2  Cherry   11     Spain
# 3     Sam   23    London

# %%
pd.concat([df2,df3])
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago
# 0    Linda   22       Thailand
# 1     Amil  345        America
# 2   Cherry   11          Spain
# 3      Sam   23         London
